# %%
import os
import pandas as pd
#os.chdir("")

# %%
hepatitis=pd.read_csv("hepatitis.txt",na_values=["?",","], names = ['target','age','gender','steroid',
                              'antivirals','fatigue','malaise',
                              'anorexia','liverBig','liverFirm',
                              'spleen','spiders','ascites',
                              'varices','bili','alk','sgot',
                              'albu','protime','histology'])
print(hepatitis.shape)
print(type(hepatitis))
# Out:
# (155, 20)
# <class 'pandas.core.frame.DataFrame'>

# %%
print(hepatitis.columns)
print(hepatitis.dtypes)
# Out:
# Index(['target', 'age', 'gender', 'steroid', 'antivirals', 'fatigue',
#        'malaise', 'anorexia', 'liverBig', 'liverFirm', 'spleen', 'spiders',
#        'ascites', 'varices', 'bili', 'alk', 'sgot', 'albu', 'protime',
#        'histology'],
#       dtype='object')
# target          int64
# age             int64
# gender          int64
# steroid       float64
# antivirals      int64
# fatigue       float64
# malaise       float64
# anorexia      float64
# liverBig      float64
# liverFirm     float64
# spleen        float64
# spiders       float64
# ascites       float64
# varices       float64
# bili          float64
# alk           float64
# sgot          float64
# albu          float64
# protime       float64
# histology       int64
# dtype: object

# %%
hepatitis["target"].value_counts()
# Out:
# 2    123
# 1     32
# Name: target, dtype: int64

# %%
# from die as 1 and live as 2 
# convert die as 1 and live as 0
hepatitis['target'] = hepatitis['target'].map({1: 1, 2: 0})

# %%
hepatitis["target"].value_counts()
# Out:
# 0    123
# 1     32
# Name: target, dtype: int64

# %%
num_data = hepatitis[["age", "bili", "alk", "sgot", "albu", "protime"]]
cat_data = hepatitis.drop(["age", "bili", "alk", "sgot", "albu", "protime"], axis=1)
print(num_data.columns)
print(cat_data.columns)
# Out:
# Index(['age', 'bili', 'alk', 'sgot', 'albu', 'protime'], dtype='object')
# Index(['target', 'gender', 'steroid', 'antivirals', 'fatigue', 'malaise',
#        'anorexia', 'liverBig', 'liverFirm', 'spleen', 'spiders', 'ascites',
#        'varices', 'histology'],
#       dtype='object')

# %%
# convert numeric attr to numeric type
num_data.apply(pd.to_numeric)
# Out:
#      age  bili    alk   sgot  albu  protime
# 0     30   1.0   85.0   18.0   4.0      NaN
# 1     50   0.9  135.0   42.0   3.5      NaN
# 2     78   0.7   96.0   32.0   4.0      NaN
# 3     31   0.7   46.0   52.0   4.0     80.0
# 4     34   1.0    NaN  200.0   4.0      NaN
# 5     34   0.9   95.0   28.0   4.0     75.0
# 6     51   NaN    NaN    NaN   NaN      NaN
# 7     23   1.0    NaN    NaN   NaN      NaN
# 8     39   0.7    NaN   48.0   4.4      NaN
# 9     30   1.0    NaN  120.0   3.9      NaN
# 10    39   1.3   78.0   30.0   4.4     85.0
# 11    32   1.0   59.0  249.0   3.7     54.0
# 12    41   0.9   81.0   60.0   3.9     52.0
# 13    30   2.2   57.0  144.0   4.9     78.0
# 14    47   NaN    NaN   60.0   NaN      NaN
# 15    38   2.0   72.0   89.0   2.9     46.0
# 16    66   1.2  102.0   53.0   4.3      NaN
# 17    40   0.6   62.0  166.0   4.0     63.0
# 18    38   0.7   53.0   42.0   4.1     85.0
# 19    38   0.7   70.0   28.0   4.2     62.0
# ...

# %%
# convert cat attr to cat type
cat_data.apply(pd.Categorical)
# Out:
#     target gender steroid antivirals fatigue malaise anorexia liverBig  \
# 0        0      2     1.0          2     2.0     2.0      2.0      1.0
# 1        0      1     1.0          2     1.0     2.0      2.0      1.0
# 2        0      1     2.0          2     1.0     2.0      2.0      2.0
# 3        0      1     NaN          1     2.0     2.0      2.0      2.0
# 4        0      1     2.0          2     2.0     2.0      2.0      2.0
# 5        0      1     2.0          2     2.0     2.0      2.0      2.0
# 6        1      1     1.0          2     1.0     2.0      1.0      2.0
# 7        0      1     2.0          2     2.0     2.0      2.0      2.0
# 8        0      1     2.0          2     1.0     2.0      2.0      2.0
# 9        0      1     2.0          2     2.0     2.0      2.0      2.0
# 10       0      1     1.0          1     2.0     2.0      2.0      1.0
# 11       0      1     2.0          1     1.0     2.0      2.0      2.0
# ...

# %%
print(num_data.isnull().sum().sum())
print(cat_data.isnull().sum().sum())
# Out:
# 122
# 45

# %%
num_data=num_data.fillna(num_data.mean())

from sklearn.preprocessing import Imputer
imputer = Imputer(missing_values='NaN',strategy='most_frequent',axis=1)
imputer.fit(cat_data)
cat_data_imputed = imputer.transform(cat_data.values)

# %%
print(num_data.isnull().sum().sum())
print(cat_data.isnull().sum().sum())
# Out:
# 0
# 45

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(num_data)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
# combine the num and cat data
hep_data = num_data.append(cat_data, ignore_index=True)
hep_data
# Out:
# /Users/amithprasad/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py:6201: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
#   sort=sort)
#       age      albu         alk  anorexia  antivirals  ascites      bili  \
# 0    30.0  4.000000   85.000000       NaN         NaN      NaN  1.000000
# 1    50.0  3.500000  135.000000       NaN         NaN      NaN  0.900000
# 2    78.0  4.000000   96.000000       NaN         NaN      NaN  0.700000
# 3    31.0  4.000000   46.000000       NaN         NaN      NaN  0.700000
# 4    34.0  4.000000  105.325397       NaN         NaN      NaN  1.000000
# 5    34.0  4.000000   95.000000       NaN         NaN      NaN  0.900000
# 6    51.0  3.817266  105.325397       NaN         NaN      NaN  1.427517
# ...

# %%
from sklearn import preprocessing, metrics, cross_validation
from sklearn.model_selection import train_test_split

# %%
# Divide into train and test
y=hep_data["target"]
X=hep_data.drop('target', axis=1)

#from sklearn.model_selection import train_test_split  
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (248, 19)
# (62, 19)
# (248,)
# (62,)

# %%
X_train.isnull().sum()
# Out:
# age           125
# albu          125
# alk           125
# anorexia      123
# antivirals    123
# ascites       127
# bili          125
# fatigue       123
# gender        123
# histology     123
# liverBig      132
# liverFirm     133
# malaise       123
# protime       125
# sgot          125
# spiders       127
# spleen        127
# steroid       123
# varices       127
# dtype: int64

# %%
X_test.isnull().sum()
# Out:
# age           30
# albu          30
# alk           30
# anorexia      33
# antivirals    32
# ascites       33
# bili          30
# fatigue       33
# gender        32
# histology     32
# liverBig      33
# liverFirm     33
# malaise       33
# protime       30
# sgot          30
# spiders       33
# spleen        33
# steroid       33
# varices       33
# dtype: int64

# %%
# Import the model we are using
from sklearn.ensemble import RandomForestClassifier

# %%
# Instantiate model with 1000 decision trees
rf = RandomForestClassifier(n_estimators = 200, random_state = 42)

# Train the model on training data
rf.fit(X_train, y_train);
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-118-07f9c1614c94> in <module>()
#       3
#       4 # Train the model on training data
# ----> 5 rf.fit(X_train, y_train);
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py in fit(self, X, y, sample_weight)
#     245         """
#     246         # Validate or convert input data
# --> 247         X = check_array(X, accept_sparse="csc", dtype=DTYPE)
#     248         y = check_array(y, accept_sparse='csc', ensure_2d=False, dtype=None)
#     249         if sample_weight is not None:
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     451                              % (array.ndim, estimator_name))
# ...

# %%
model.coef_
# Out:
# array([[-0.16399497,  0.23371589,  1.47542868, -0.02739724,  0.2519407 ,
#          0.1589189 ,  0.04316058, -0.1714085 ,  0.53897912, -0.13484518,
#         -0.27258375, -0.82469471,  0.42206368,  0.47413564]])

# %%
model.intercept_
# Out:
# array([-2.87261741])

# %%
# Predict on Test with max_depth=2,max_depth=5
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,y_pred))
# Out:
# 0.959

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test,y_pred))
# Out:
# [[900   5]
#  [ 36  59]]

# %%
from sklearn.metrics import recall_score
print(recall_score(y_test,y_pred, pos_label=1, average='binary'))
# Out:
# 0.6210526315789474

# %% [markdown]
# # Build SVM Classifier with weights

# %%
model1= svm.SVC(C=10,kernel='linear',class_weight={1: 7,0:0.5})
model1.fit(X_train,y_train)
# Out:
# SVC(C=10, cache_size=200, class_weight={1: 7, 0: 0.5}, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
# Predict on Test 
y_pred = model1.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,y_pred))
# Out:
# 0.887

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test,y_pred))
# Out:
# [[798 107]
#  [  6  89]]

# %%
from sklearn.metrics import recall_score
print(recall_score(y_test,y_pred, pos_label=1, average='binary'))
# Out:
# 0.9368421052631579

# %% [markdown]
# # GridSearch Cross Validation

# %%
#from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import GridSearchCV
Cs = [0.001, 0.01, 0.1, 1, 10]
gammas = [0.001, 0.01, 0.1, 1]
param_grid = {'C': Cs, 'gamma' : gammas}
clf = GridSearchCV(svm.SVC(kernel='rbf',class_weight={1: 2,0:0.5}), param_grid, n_jobs=4,scoring='recall')
clf.fit(X=X_train, y=y_train)
svm_model = clf.best_estimator_
print (clf.best_score_, clf.best_params_)
# Out:
# 0.9039070978682171 {'C': 10, 'gamma': 0.01}

# %%
y_pred_test=svm_model.predict(X_test)
print(accuracy_score(y_test,y_pred_test))
# Out:
# 0.974

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test,y_pred_test))
# Out:
# [[890  15]
#  [ 11  84]]

# %%
from sklearn.metrics import recall_score
print(recall_score(y_test,y_pred_test, pos_label=1, average='binary'))
# Out:
# 0.893203883495

# %% [markdown]
# Explore function SVM regressor
# http://scikit-learn.org/stable/modules/svm.html
